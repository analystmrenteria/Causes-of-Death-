# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob as gb
import numpy as np

# %%
cause_of_death = pd.read_csv('C:\\Users\\mrent\\OneDrive\\Documents\\Springboard\\Personal Projects\\Cause of Death\\20222703 Causes Of Death Clean Output V2.0.csv')

# %%
cod = cause_of_death

# %%
cod.head()
# Out:
#                       Causes name  \
# 0                      Meningitis
# 1                       Neoplasms
# 2  Fire, heat, and hot substances
# 3                         Malaria
# 4                        Drowning
#
#                              Causes Full Description  Death Numbers  \
# 0  Deaths - Meningitis - Sex: Both - Age: All Age...         2933.0
# 1  Deaths - Neoplasms - Sex: Both - Age: All Ages...        15925.0
# 2  Deaths - Fire, heat, and hot substances - Sex:...          481.0
# 3  Deaths - Malaria - Sex: Both - Age: All Ages (...          393.0
# 4  Deaths - Drowning - Sex: Both - Age: All Ages ...         2127.0
#
#         Entity Code  Year
# 0  Afghanistan  AFG  2007
# 1  Afghanistan  AFG  2007
# 2  Afghanistan  AFG  2007
# 3  Afghanistan  AFG  2007
# 4  Afghanistan  AFG  2007

# %%
cod.index
# Out:
# RangeIndex(start=0, stop=201762, step=1)

# %%
cod.columns
# Out:
# Index(['Causes name', 'Causes Full Description', 'Death Numbers', 'Entity',
#        'Code', 'Year'],
#       dtype='object')

# %%
cod.count()
# Out:
# Causes name                201762
# Causes Full Description    201762
# Death Numbers              190575
# Entity                     201762
# Code                       200277
# Year                       201762
# dtype: int64

# %%
cod.dtypes
# Out:
# Causes name                 object
# Causes Full Description     object
# Death Numbers              float64
# Entity                      object
# Code                        object
# Year                         int64
# dtype: object

# %%
cod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201762 entries, 0 to 201761
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Causes name              201762 non-null  object
#  1   Causes Full Description  201762 non-null  object
#  2   Death Numbers            190575 non-null  float64
#  3   Entity                   201762 non-null  object
#  4   Code                     200277 non-null  object
#  5   Year                     201762 non-null  int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.2+ MB

# %%
cod.isnull()
# Out:
#         Causes name  Causes Full Description  Death Numbers  Entity   Code  \
# 0             False                    False          False   False  False
# 1             False                    False          False   False  False
# 2             False                    False          False   False  False
# 3             False                    False          False   False  False
# 4             False                    False          False   False  False
# ...             ...                      ...            ...     ...    ...
# 201757        False                    False          False   False  False
# 201758        False                    False          False   False  False
# 201759        False                    False          False   False  False
# 201760        False                    False          False   False  False
# 201761        False                    False           True   False  False
#
#          Year
# 0       False
# 1       False
# 2       False
# ...

# %%
cod.isnull().sum()
# Out:
# Causes name                    0
# Causes Full Description        0
# Death Numbers              11187
# Entity                         0
# Code                        1485
# Year                           0
# dtype: int64

# %%
cod['Death Numbers']= cod['Death Numbers'].fillna('0')

# %%
cod
# Out:
#                                          Causes name  \
# 0                                         Meningitis
# 1                                          Neoplasms
# 2                     Fire, heat, and hot substances
# 3                                            Malaria
# 4                                           Drowning
# ...                                              ...
# 201757                            Digestive diseases
# 201758                               Acute hepatitis
# 201759       Alzheimer's disease and other dementias
# 201760                           Parkinson's disease
# 201761  Number of executions (Amnesty International)
#
#                                   Causes Full Description Death Numbers  \
# 0       Deaths - Meningitis - Sex: Both - Age: All Age...        2933.0
# 1       Deaths - Neoplasms - Sex: Both - Age: All Ages...       15925.0
# 2       Deaths - Fire, heat, and hot substances - Sex:...         481.0
# ...

# %%
cod.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 201757    False
# 201758    False
# 201759    False
# 201760    False
# 201761    False
# Length: 201762, dtype: bool

# %%
cod['Causes Full Description'].describe()
# Out:
# count                                                201762
# unique                                                   33
# top       Deaths - Meningitis - Sex: Both - Age: All Age...
# freq                                                   6114
# Name: Causes Full Description, dtype: object

# %%
cod.loc[10, 'Causes Full Description'] =1

# %%
cod
# Out:
#                                          Causes name  \
# 0                                         Meningitis
# 1                                          Neoplasms
# 2                     Fire, heat, and hot substances
# 3                                            Malaria
# 4                                           Drowning
# ...                                              ...
# 201757                            Digestive diseases
# 201758                               Acute hepatitis
# 201759       Alzheimer's disease and other dementias
# 201760                           Parkinson's disease
# 201761  Number of executions (Amnesty International)
#
#                                   Causes Full Description Death Numbers  \
# 0       Deaths - Meningitis - Sex: Both - Age: All Age...        2933.0
# 1       Deaths - Neoplasms - Sex: Both - Age: All Ages...       15925.0
# 2       Deaths - Fire, heat, and hot substances - Sex:...         481.0
# ...

# %%
to_drop = ['Causes Full Description', 'Code']
cod.drop(to_drop, inplace=True, axis=1)

# %%
cod
# Out:
#                                          Causes name Death Numbers  \
# 0                                         Meningitis        2933.0
# 1                                          Neoplasms       15925.0
# 2                     Fire, heat, and hot substances         481.0
# 3                                            Malaria         393.0
# 4                                           Drowning        2127.0
# ...                                              ...           ...
# 201757                            Digestive diseases        4437.0
# 201758                               Acute hepatitis         136.0
# 201759       Alzheimer's disease and other dementias         812.0
# 201760                           Parkinson's disease         232.0
# 201761  Number of executions (Amnesty International)             0
#
#              Entity  Year
# 0       Afghanistan  2007
# 1       Afghanistan  2007
# 2       Afghanistan  2007
# 3       Afghanistan  2007
# ...

# %%
cod.dtypes
# Out:
# Causes name      object
# Death Numbers    object
# Entity           object
# Year              int64
# dtype: object

# %%
cod.drop_duplicates(inplace=True)

# %%
cod
# Out:
#                                          Causes name Death Numbers  \
# 0                                         Meningitis        2933.0
# 1                                          Neoplasms       15925.0
# 2                     Fire, heat, and hot substances         481.0
# 3                                            Malaria         393.0
# 4                                           Drowning        2127.0
# ...                                              ...           ...
# 201757                            Digestive diseases        4437.0
# 201758                               Acute hepatitis         136.0
# 201759       Alzheimer's disease and other dementias         812.0
# 201760                           Parkinson's disease         232.0
# 201761  Number of executions (Amnesty International)             0
#
#              Entity  Year
# 0       Afghanistan  2007
# 1       Afghanistan  2007
# 2       Afghanistan  2007
# 3       Afghanistan  2007
# ...

# %%
cod['Death Numbers'] = cod['Death Numbers'].astype(int)

# %%
cod
# Out:
#                                          Causes name  Death Numbers  \
# 0                                         Meningitis           2933
# 1                                          Neoplasms          15925
# 2                     Fire, heat, and hot substances            481
# 3                                            Malaria            393
# 4                                           Drowning           2127
# ...                                              ...            ...
# 201757                            Digestive diseases           4437
# 201758                               Acute hepatitis            136
# 201759       Alzheimer's disease and other dementias            812
# 201760                           Parkinson's disease            232
# 201761  Number of executions (Amnesty International)              0
#
#              Entity  Year
# 0       Afghanistan  2007
# 1       Afghanistan  2007
# 2       Afghanistan  2007
# 3       Afghanistan  2007
# ...
